# %%
from math import log
import operator
import os
import math
import sys
import collections

def main():
    
    lines = read_csv()
    lables = lines[0]
    lables = lables[0:(len(lables)-1)]
    values = lines[1:(len(lines))]
    values = update_decision_column(values)
    values = update_null(values)
    decisiontree = tree(values, lables)
    f = open('tree.txt','w')
    f.write(str(decisiontree))
    f.close()
    print(decisiontree)

def tree(data,labels):
    classList = [ex[-1] for ex in data]
    if classList.count(classList[0]) == len(classList):
        return classList[0]
    if len(data[0]) == 1:
        return majority(classList)
    bestFeat = choose(data)
    bestFeatLabel = labels[bestFeat]
    theTree = {bestFeatLabel:{}}
    del(labels[bestFeat])
    featValues = [ex[bestFeat] for ex in data]
    uniqueVals = set(featValues)
    for value in uniqueVals:
        subLabels = labels[:]
        theTree[bestFeatLabel][value] = tree(split(data, bestFeat, value),subLabels)
    return theTree

def read_csv():
    list1 = []
    fh = open('delaytraining.csv', 'r')
    for line in fh:
        list1.append(line.strip().split(','))
                   
    return list1

def update_decision_column(decision1):
    i=0
    for values2 in decision1:
        int_value = values2[-1]
        if not values2[-1]:
            values2[-1]='Diverted'            
        else:
            int_value = int(values2[-1])
            if int_value<0:
                values2[-1]='Early'
            elif int_value==0:
                values2[-1]='On_time'
            else:
                values2[-1]='Delayed'
        decision1[i]=values2
        i+=1
    return decision1

def update_null(data1):
    i=0
    for values3 in data1:
        j=0
        for x in values3:
            if not x:
                values3[j]='0'
            j+=1
        data1[i]=values3
        
        i+=1
        
    return data1
    
    
def check_null(value):
    if not value:
        return 0
    return value
    
def entropy(data):
    entries = len(data)
    labels = {}
    for feat in data:
        label = feat[-1]
        if label not in labels.keys():
            labels[label] = 0
        labels[label] += 1
    entropy = 0.0
    for key in labels:
        probability = float(labels[key])/entries
        entropy -= probability * log(probability,2)
    return entropy

def split(data, axis, val):
    newData = []
    for feat in data:
        if feat[axis] == val:
            reducedFeat = feat[:axis]
            reducedFeat.extend(feat[axis+1:])
            newData.append(reducedFeat)
    return newData

def choose(data):
    features = len(data[0]) - 1
    baseEntropy = entropy(data)
    bestInfoGain = 0.0;
    bestFeat = -1
    for i in range(features):
        featList = [ex[i] for ex in data]
        uniqueVals = set(featList)
        newEntropy = 0.0
        for value in uniqueVals:
            newData = split(data, i, value)
            probability = len(newData)/float(len(data))
            newEntropy += probability * entropy(newData)
        infoGain = baseEntropy - newEntropy
        if (infoGain > bestInfoGain):
            bestInfoGain = infoGain
            bestFeat = i
    return bestFeat

def majority(classList):
    classCount={}
    for vote in classList:
        if vote not in classCount.keys(): classCount[vote] = 0
        classCount[vote] += 1
    sortedClassCount = sorted(classCount.iteritems(), key=operator.itemgetter(1), reverse=True)
    return sortedClassCount[0][0]
main()
# Out:
# {'LATE_AIRCRAFT_DELAY': {'20': 'Delayed', '50': 'Delayed', '16': 'Delayed', '14': 'Delayed', '40': 'Delayed', '33': 'Delayed', '25': 'Delayed', '53': 'Delayed', '19': 'Delayed', '21': 'Delayed', '47': 'Delayed', '71': 'Delayed', '149': 'Delayed', '23': 'Delayed', '63': 'Delayed', '165': 'Delayed', '11': 'Delayed', '68': 'Delayed', '43': 'Delayed', '67': 'Delayed', '209': 'Delayed', '111': 'Delayed', '26': 'Delayed', '13': 'Delayed', '8': 'Delayed', '10': 'Delayed', '51': 'Delayed', '4': 'Delayed', '151': 'Delayed', '133': 'Delayed', '160': 'Delayed', '56': 'Delayed', '7': 'Delayed', '73': 'Delayed', '101': 'Delayed', '18': 'Delayed', '9': 'Delayed', '52': 'Delayed', '12': 'Delayed', '132': 'Delayed', '59': 'Delayed', '74': 'Delayed', '41': 'Delayed', '5': 'Delayed', '24': 'Delayed', '77': 'Delayed', '70': 'Delayed', '0': {'NAS_DELAY': {'32': 'Delayed', '20': 'Delayed', '123': 'Delayed', '14': 'Delayed', '115': 'Delayed', '22': 'Delayed', '41': 'Delayed', '25': 'Delayed', '59': 'Delayed', '21': 'Delayed', '0': {'CANCELLED': {'1': 'Diverted', '0': {'CARRIER_DELAY': {'291': 'Delayed', '94': 'Delayed', '77': 'Delayed', '60': 'Delayed', '33': 'Delayed', '20': 'Delayed', '53': 'Delayed', '19': 'Delayed', '21': 'Delayed', '0': {'DIVERTED': {'1': 'Diverted', '0': {'ORIGIN': {'ASE': {'WEATHER_DELAY': {'16': 'Delayed', '0': {'DEST': {'LAX': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}, 'SFO': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}}}}}, 'ACV': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}, 'ABQ': {'DEST': {'OAK': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}, 'LAX': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}, 'SFO': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}, 'SAN': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}}}, 'ATL': {'DEST': {'OAK': 'Early', 'LAX': {'SECURITY_DELAY': {'On_time': 'On_time', 'Delayed': 'Delayed', 'Early': 'Early'}}, 'SFO': {'WEATHER_DELAY': {'33': 'Delayed', '0': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}}}, 'SAN': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}, 'SMF': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}, 'SNA': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}, 'ONT': 'Early', 'SJC': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}}}, 'ANC': {'SECURITY_DELAY': {'Delayed': 'Delayed', 'Early': 'Early'}}}}}}, '16': 'Delayed', '125': 'Delayed', '71': 'Delayed', '44': 'Delayed', '36': 'Delayed', '137': 'Delayed', '37': 'Delayed', '196': 'Delayed', '17': 'Delayed', '78': 'Delayed', '97': 'Delayed', '293': 'Delayed', '82': 'Delayed', '24': 'Delayed', '26': 'Delayed', '112': 'Delayed', '153': 'Delayed', '65': 'Delayed', '154': 'Delayed'}}}}, '45': 'Delayed', '24': 'Delayed', '71': 'Delayed', '29': 'Delayed', '55': 'Delayed', '27': 'Delayed', '28': 'Delayed', '49': 'Delayed', '36': 'Delayed', '37': 'Delayed', '222': 'Delayed', '26': 'Delayed', '17': 'Delayed', '12': 'Delayed', '8': 'Delayed', '18': 'Delayed', '19': 'Delayed', '146': 'Delayed', '3': 'Delayed', '48': 'Delayed', '92': 'Delayed', '5': 'Delayed', '56': 'Delayed', '15': 'Delayed', '73': 'Delayed', '64': 'Delayed', '16': 'Delayed', '7': 'Delayed', '136': 'Delayed', '23': 'Delayed', '9': 'Delayed', '2': 'Delayed'}}, '78': 'Delayed', '6': 'Delayed', '27': 'Delayed', '28': 'Delayed', '85': 'Delayed', '100': 'Delayed', '49': 'Delayed', '36': 'Delayed', '35': 'Delayed', '17': 'Delayed', '90': 'Delayed', '46': 'Delayed', '97': 'Delayed', '30': 'Delayed', '148': 'Delayed', '31': 'Delayed', '44': 'Delayed', '167': 'Delayed', '66': 'Delayed', '2': 'Delayed', '99': 'Delayed', '145': 'Delayed', '22': 'Delayed', '32': 'Delayed', '38': 'Delayed', '87': 'Delayed'}}
